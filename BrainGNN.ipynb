# %%
# %cd /content
# !git clone https://github.com/que-naomi/BrainGNN_Pytorch
# Out:
# /content
# Cloning into 'BrainGNN_Pytorch'...
# remote: Enumerating objects: 103, done.
# remote: Counting objects: 100% (97/97), done.
# remote: Compressing objects: 100% (75/75), done.
# remote: Total 103 (delta 34), reused 71 (delta 19), pack-reused 6
# Receiving objects: 100% (103/103), 66.40 KiB | 1.28 MiB/s, done.
# Resolving deltas: 100% (34/34), done.

# %%
# %cd /content/BrainGNN_Pytorch
# !pip install nilearn
# !pip install tensorboardX
# !pip install deepdish
# Out:
# /content/BrainGNN_Pytorch
# ...

# %%
# !python 01-fetch_data.py
# Out:
# Namespace(pipeline='cpac', atlas='cc200', download=True)
# ...
#  ...done. (2 seconds, 0 min)
# ...
#  ...done. (2 seconds, 0 min)
# ...
#  ...done. (2 seconds, 0 min)
# ...
#  ...done. (2 seconds, 0 min)
# ...
#  ...done. (2 seconds, 0 min)
# ...
#  ...done. (2 seconds, 0 min)
# ...
#  ...done. (2 seconds, 0 min)
# ...
#  ...done. (2 seconds, 0 min)
# ...
#  ...done. (2 seconds, 0 min)
# ...
#  ...done. (2 seconds, 0 min)
# ...
#  ...done. (2 seconds, 0 min)
# ...
#  ...done. (2 seconds, 0 min)
# ...
#  ...done. (2 seconds, 0 min)
# ...
#  ...done. (2 seconds, 0 min)
# ...
#  ...done. (2 seconds, 0 min)
# ...
#  ...done. (2 seconds, 0 min)
# ...
#  ...done. (2 seconds, 0 min)
# ...
#  ...done. (2 seconds, 0 min)
# ...
#  ...done. (2 seconds, 0 min)
# ...
#  ...done. (2 seconds, 0 min)
# ...
#  ...done. (2 seconds, 0 min)
# ...
#  ...done. (2 seconds, 0 min)
# ...
#  ...done. (2 seconds, 0 min)
# ...
# Downloaded 180224 of 391748 bytes (46.0%,    1.3s remaining) ...done. (3 seconds, 0 min)
# ...
# Downloaded 163840 of 397377 bytes (41.2%,    1.6s remaining) ...done. (3 seconds, 0 min)
# ...
#  ...done. (2 seconds, 0 min)
# ...

# %%
# !python 02-process_data.py
# Out:
# Arguments:
#  Namespace(atlas='cc200', seed=123, nclass=2)

# %%
# !pip install torch-scatter -f https://pytorch-geometric.com/whl/torch-1.10.0+cu111.html
# !pip install torch-sparse -f https://pytorch-geometric.com/whl/torch-1.10.0+cu111.html
# !pip install torch-cluster -f https://pytorch-geometric.com/whl/torch-1.10.0+cu111.html
# !pip install torch-spline-conv -f https://pytorch-geometric.com/whl/torch-1.10.0+cu111.html
# !pip install torch-geometric
# Out:
# Looking in links: https://pytorch-geometric.com/whl/torch-1.10.0+cu111.html
# ...
# Looking in links: https://pytorch-geometric.com/whl/torch-1.10.0+cu111.html
# ...
# Looking in links: https://pytorch-geometric.com/whl/torch-1.10.0+cu111.html
# ...
# Looking in links: https://pytorch-geometric.com/whl/torch-1.10.0+cu111.html
# ...

# %%
# !pip uninstall lida  # Uninstall the conflicting package
# !pip uninstall networkx  # Uninstall the currently installed version

# Install networkx first with the required version
# !pip install networkx==2.5

# Then install lida
# !pip install lida
# Out:
# Found existing installation: lida 0.0.10
# Uninstalling lida-0.0.10:
#   Would remove:
#     /usr/local/bin/lida
#     /usr/local/lib/python3.10/dist-packages/lida-0.0.10.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/lida/*
# Proceed (Y/n)?

# %%
# !python 03-main.py
# Out:
# /content/BrainGNN_Pytorch/imports/gdc.py:13: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   return numba.jit(cache=True)(func)
# Processing...
# Time:  197.98292602199945
# /usr/local/lib/python3.10/dist-packages/torch_geometric/data/in_memory_dataset.py:284: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
# Done!
# ...
